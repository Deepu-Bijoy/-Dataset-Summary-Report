# %% [markdown]
# # Dataset Summary Report – Day 7
#
# Pandas-based CSV dataset exploration.

# %% [markdown]
# ## 1. Import Pandas

# %%
import pandas as pd
print('Pandas version:', pd.__version__)

# %% [markdown]
# ## 2. Load CSV Dataset
#
# Upload the CSV from the LMS to Google Colab and set its filename below.

# %%
file_name = 'dataset.csv'
df = pd.read_csv(file_name)
print('Dataset loaded successfully!')

# %% [markdown]
# ## 3. First 5 Rows

# %%
df.head()

# %% [markdown]
# ## 4. Last 5 Rows

# %%
df.tail()

# %% [markdown]
# ## 5. Random Samples

# %%
df.sample(min(5, len(df)), random_state=42)

# %% [markdown]
# ## 6. Shape

# %%
print('Rows:', df.shape[0])
print('Columns:', df.shape[1])

# %% [markdown]
# ## 7. Columns and Index

# %%
print('Columns:', df.columns.tolist())
print('Index:', df.index)

# %% [markdown]
# ## 8. Data Types

# %%
print(df.dtypes)

# %% [markdown]
# ## 9. Dataset Information

# %%
df.info()

# %% [markdown]
# ## 10. Descriptive Statistics

# %%
df.describe(include='all').T

# %% [markdown]
# ## 11. Missing Values

# %%
missing = df.isnull().sum()
print(missing)
print('\nTotal missing values:', missing.sum())

# %% [markdown]
# ## 12. Basic Observations

# %%
print(f'The dataset contains {df.shape[0]} rows and {df.shape[1]} columns.')
print(f'Available features/columns: {len(df.columns)}')
print(f'Total missing values: {df.isnull().sum().sum()}')
print('\nData types:')
print(df.dtypes)

# %% [markdown]
# ## Conclusion
#
# The dataset was loaded and explored using Pandas, including structure, samples, dimensions, data types, descriptive statistics, and missing values.
